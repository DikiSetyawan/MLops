# %%
import pandas as pd
df = pd.read_csv(r'D:\project\porto\data\data.csv')
df.head()
# Out:
#         City  Temperature (C)           Weather  Humidity (%)  \
# 0    Jakarta            29.00  scattered clouds            67
# 1   Surabaya            26.97        few clouds            83
# 2  Palembang            30.05  scattered clouds            70
# 3    Bandung            21.01  scattered clouds            92
# 4    Jakarta            29.00  scattered clouds            68
#
#    Wind Speed (m/s)                 time
# 0              4.12  2024-07-17 20:11:53
# 1              5.14  2024-07-17 20:11:53
# 2              4.12  2024-07-17 20:11:53
# 3              0.45  2024-07-17 20:11:53
# 4              4.12  2024-07-17 20:22:13

# %%
jak = df[df['City']=='Jakarta']['Humidity (%)']
print(jak)
# Out:
# 0     67
# 4     68
# 8     68
# 12    68
# 16    68
# 20    68
# 24    68
# 28    68
# 32    67
# 36    68
# 40    68
# Name: Humidity (%), dtype: int64
